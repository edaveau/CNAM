# %% [markdown]
# The part below allows to retrieve the necessary packages in order for the script to run correctly. We also included the APK which allows us to connect to the Open Data SNCF API. You may remove the # at the beginning of the script should you need to install packages.

# %%
#import sys
#!{sys.executable} -m pip install requests;
#!{sys.executable} -m pip install json;
#!{sys.executable} -m pip install pandas;
#!{sys.executable} -m pip install datetime;

# %%
import requests as r
import json as j
import pandas as pd
import datetime
from pandas.io.json import json_normalize
from requests.auth import HTTPBasicAuth

user = "PASTE YOUR API KEY HERE"
coverage = "fr-idf"
url_stations = "https://api.sncf.com/v1/coverage/sncf/physical_modes/physical_mode%3ALongDistanceTrain/stop_points//?count=1000&"
url_lines = "https://api.sncf.com/v1/coverage/sncf/physical_modes/physical_mode%3ALongDistanceTrain/lines//?count=1000&"
url_theoTimes = "https://api.sncf.com/v1/coverage/sncf/physical_modes/physical_mode%3ALongDistanceTrain/vehicle_journeys//?count=1000&since=20190320T205354&"
url_realTimes = "https://api.sncf.com/v1/coverage/sncf/physical_modes/physical_mode%3ALongDistanceTrain/disruptions//?count=1000&since=20190320T205354&"
headers={'Authorization': 'TOK:apk'}

# %% [markdown]
# Here, we request the data from the SNCF API. The response codes are shown below to ensure we correctly retrieved each dataset.

# %%
response_stations = r.get(url_stations, 
                 auth=HTTPBasicAuth(user, ""))
response_lines = r.get(url_lines, 
                 auth=HTTPBasicAuth(user, ""))
response_theoTimes = r.get(url_theoTimes, 
                 auth=HTTPBasicAuth(user, ""))
response_realTimes = r.get(url_realTimes, 
                 auth=HTTPBasicAuth(user, ""))
print(" Response code for the stations request: ", response_stations.status_code, "\n",
    "Response code for the lines request: ", response_lines.status_code, "\n",
    "Response code for the theoretical times request: ", response_theoTimes.status_code, "\n",
    "Response code for the real times request: ", response_realTimes.status_code)
# Out:
#  Response code for the stations request:  200
#  Response code for the lines request:  200
#  Response code for the theoretical times request:  200
#  Response code for the real times request:  200

# %% [markdown]
# Then, we can load the data in a dictionary on Python. We also print the keys in order to have a view on the relevance of the data we collected.

# %%
json_stations = j.loads(response_stations.text)
json_lines = j.loads(response_lines.text)
json_theoTimes = j.loads(response_theoTimes.text)
json_realTimes = j.loads(response_realTimes.text)
print("Class and main keys from the stations data : ", type(json_stations))
for key, value in json_stations.items() :
    print (key)

print("\nClass and main keys from the lines data : ", type(json_lines))
for key, value in json_lines.items() :
    print (key)
    
print("\nClass and main keys from the theoretical times data : ", type(json_theoTimes))
for key, value in json_theoTimes.items() :
    print (key)
    
print("\nClass and main keys from the real times data : ", type(json_realTimes))
for key, value in json_realTimes.items() :
    print (key)
# Out:
# Class and main keys from the stations data :  <class 'dict'>
# pagination
# links
# disruptions
# feed_publishers
# context
# stop_points
#
# Class and main keys from the lines data :  <class 'dict'>
# pagination
# links
# disruptions
# lines
# feed_publishers
# context
#
# Class and main keys from the theoretical times data :  <class 'dict'>
# pagination
# links
# disruptions
# feed_publishers
# context
# vehicle_journeys
#
# Class and main keys from the real times data :  <class 'dict'>
# disruptions
# pagination
# links
# context
# feed_publishers

# %% [markdown]
# As we can see, data were correctly retrieved in JSON format, which we then converted to a dictionary format. The main issue is that all the records of interest are respectively contained within the "stop_points", "lines", "vehicle_journeys" and "disruptions" sub-dictionaries. Therefore, we first need to extract it.

# %%
keys_to_remove_stations = ["pagination", "links", "disruptions", "feed_publishers", "context"]
keys_to_remove_lines = ["pagination", "links", "disruptions", "feed_publishers", "context"]
keys_to_remove_theoTimes = ["pagination", "links", "disruptions", "feed_publishers", "context"]
keys_to_remove_realTimes = ["pagination", "links", "feed_publishers", "context"]
for k in keys_to_remove_stations :
    json_stations.pop(k, None)
for k in keys_to_remove_lines :
    json_stations.pop(k, None)
for k in keys_to_remove_theoTimes :
    json_stations.pop(k, None)
for k in keys_to_remove_realTimes :
    json_stations.pop(k, None)

# %% [markdown]
# We have correctly removed irrelevant data from the main dictionary. However, the subdictionaries, which are the data of interest are contained within a list. Therefore, we first need to extract the list in order to manipulate more easily each nested dictionary.

# %%
stations = []
lines = []
theoTimes = []
realTimes = []
for station in json_stations["stop_points"]:
    stations.append(station)
for line in json_lines["lines"]:
    lines.append(line)
for theoTime in json_theoTimes["vehicle_journeys"]:
    theoTimes.append(theoTime)
for realTime in json_realTimes["disruptions"]:
    realTimes.append(realTime)
data_sample2 = [stations[0], lines[0], theoTimes[0], realTimes[0]]
data_sample2
# Out:
# [{'name': 'Aachen/Aix la Chapelle',
#   'links': [],
#   'coord': {'lat': '50.767729', 'lon': '6.091261'},
#   'label': 'Aachen/Aix la Chapelle (Aachen)',
#   'equipments': [],
#   'administrative_regions': [{'insee': '',
#     'name': 'Aachen-Mitte',
#     'level': 9,
#     'coord': {'lat': '50.756966', 'lon': '6.092983'},
#     'label': 'Aachen-Mitte',
#     'id': 'admin:osm:22146',
#     'zip_code': ''},
#    {'insee': '',
#     'name': 'Aachen',
#     'level': 8,
#     'coord': {'lat': '50.776348', 'lon': '6.083862'},
#     'label': 'Aachen',
#     'id': 'admin:osm:62564',
#     'zip_code': ''}],
#   'fare_zone': {'name': '0'},
#   'id': 'stop_point:OCE:SP:Thalys-80153452',
#   'stop_area': {'codes': [{'type': 'CR-CI-CH', 'value': '0080-153452-BV'},
#     {'type': 'CR-CI-CH', 'value': '0080-153452-BV'},
#     {'type': 'UIC8', 'value': '80153452'},
#     {'type': 'external_code', 'value': 'OCE80153452'}],
#    'name': 'Aachen/Aix la Chapelle',
#    'links': [],
#    'coord': {'lat': '50.767729', 'lon': '6.091261'},
#    'label': 'Aachen/Aix la Chapelle (Aachen)',
#    'timezone': 'Europe/Paris',
#    'id': 'stop_area:OCE:SA:80153452'}},
#  {'code': '',
#   'network': {'codes': [{'type': 'external_code', 'value': 'sncf'},
#     {'type': 'source', 'value': 'sncf'}],
#    'id': 'network:sncf',
#    'links': [],
#    'name': 'SNCF'},
#   'links': [],
#   'color': '000000',
#   'routes': [{'direction': {'embedded_type': 'stop_area',
#      'distance': '0',
#      'stop_area': {'codes': [{'type': 'CR-CI-CH', 'value': '0087-686006-BV'},
#        {'type': 'CR-CI-CH', 'value': '0087-686006-BV'},
#        {'type': 'UIC8', 'value': '87686006'},
#        {'type': 'external_code', 'value': 'OCE87686006'}],
#       'name': 'Paris-Gare-de-Lyon',
#       'links': [],
#       'coord': {'lat': '48.844924', 'lon': '2.373481'},
#       'label': 'Paris-Gare-de-Lyon (Paris)',
#       'timezone': 'Europe/Paris',
#       'id': 'stop_area:OCE:SA:87686006'},
#      'quality': 0,
#      'id': 'stop_area:OCE:SA:87686006',
#      'name': 'Paris-Gare-de-Lyon (Paris)'},
#     'name': 'Lausanne vers Paris-Gare-de-Lyon (Lyria)',
#     'links': [],
#     'is_frequence': 'False',
#     'geojson': {'type': 'MultiLineString', 'coordinates': []},
#     'direction_type': 'backward',
#     'id': 'route:OCE:230-Lyria-85011205-87686006'},
#    {'direction': {'embedded_type': 'stop_area',
#      'distance': '0',
#      'stop_area': {'codes': [{'type': 'CR-CI-CH', 'value': '0085-011205-00'},
#        {'type': 'CR-CI-CH', 'value': '0085-011205-00'},
#        {'type': 'UIC8', 'value': '85011205'},
#        {'type': 'external_code', 'value': 'OCE85011205'}],
#       'name': 'Lausanne',
#       'links': [],
#       'coord': {'lat': '46.517297', 'lon': '6.629229'},
#       'label': 'Lausanne (Lausanne)',
#       'timezone': 'Europe/Paris',
#       'id': 'stop_area:OCE:SA:85011205'},
#      'quality': 0,
#      'id': 'stop_area:OCE:SA:85011205',
#      'name': 'Lausanne (Lausanne)'},
#     'name': 'Paris-Gare-de-Lyon vers Lausanne (Lyria)',
#     'links': [],
#     'is_frequence': 'False',
#     'geojson': {'type': 'MultiLineString', 'coordinates': []},
#     'direction_type': 'forward',
#     'id': 'route:OCE:230-Lyria-87686006-85011205'}],
#   'geojson': {'type': 'MultiLineString', 'coordinates': []},
#   'text_color': '',
#   'physical_modes': [{'id': 'physical_mode:LongDistanceTrain',
#     'name': 'Train grande vitesse'}],
#   'codes': [],
#   'closing_time': '220500',
#   'opening_time': '062300',
#   'commercial_mode': {'id': 'commercial_mode:lyria', 'name': 'Lyria'},
#   'id': 'line:OCE:230',
#   'name': '(612)PARIS-LAUSANNE'},
#  {'codes': [],
#   'name': '9260',
#   'journey_pattern': {'id': 'journey_pattern:139',
#    'name': 'journey_pattern:139'},
#   'disruptions': [{'internal': True,
#     'type': 'disruption',
#     'id': '14837f60-07ed-4e90-aecc-90fcd4bf5e1c',
#     'rel': 'disruptions',
#     'templated': False},
#    {'internal': True,
#     'type': 'disruption',
#     'id': 'e03f18b9-b4b2-49e2-b3d1-063008ebb864',
#     'rel': 'disruptions',
#     'templated': False},
#    {'internal': True,
#     'type': 'disruption',
#     'id': '79ac0e5a-6bf6-4e96-893b-146d8814416a',
#     'rel': 'disruptions',
#     'templated': False},
#    {'internal': True,
#     'type': 'disruption',
#     'id': 'eaddd04e-4c99-4611-b0e6-9f40198b8eae',
#     'rel': 'disruptions',
#     'templated': False},
#    {'internal': True,
#     'type': 'disruption',
#     'id': '1740b873-1eea-4d68-8be7-526305950e56',
#     'rel': 'disruptions',
#     'templated': False},
#    {'internal': True,
#     'type': 'disruption',
#     'id': '48ddded4-768d-4bb6-9327-4df0a4e0ba99',
#     'rel': 'disruptions',
#     'templated': False}],
#   'calendars': [{'active_periods': [{'begin': '20190304', 'end': '20190330'}],
#     'week_pattern': {'monday': True,
#      'tuesday': True,
#      'friday': True,
#      'wednesday': True,
#      'thursday': True,
#      'sunday': False,
#      'saturday': False}}],
#   'stop_times': [{'stop_point': {'name': 'Lausanne',
#      'links': [],
#      'coord': {'lat': '46.517297', 'lon': '6.629229'},
#      'label': 'Lausanne (Lausanne)',
#      'equipments': [],
#      'fare_zone': {'name': '0'},
#      'id': 'stop_point:OCE:SP:Lyria-85011205'},
#     'utc_arrival_time': '052300',
#     'utc_departure_time': '052300',
#     'headsign': '9260',
#     'arrival_time': '062300',
#     'departure_time': '062300'},
#    {'stop_point': {'name': 'Vallorbe-Cff',
#      'links': [],
#      'coord': {'lat': '46.712222', 'lon': '6.370811'},
#      'label': 'Vallorbe-Cff (Vallorbe)',
#      'equipments': [],
#      'fare_zone': {'name': '0'},
#      'id': 'stop_point:OCE:SP:Lyria-85011031'},
#     'utc_arrival_time': '060000',
#     'utc_departure_time': '060000',
#     'headsign': '9260',
#     'arrival_time': '070000',
#     'departure_time': '070000'},
#    {'stop_point': {'name': 'Frasne',
#      'links': [],
#      'coord': {'lat': '46.857441', 'lon': '6.15769'},
#      'label': 'Frasne (Frasne)',
#      'equipments': [],
#      'fare_zone': {'name': '0'},
#      'id': 'stop_point:OCE:SP:Lyria-87715136'},
#     'utc_arrival_time': '061300',
#     'utc_departure_time': '061500',
#     'headsign': '9260',
#     'arrival_time': '071300',
#     'departure_time': '071500'},
#    {'stop_point': {'name': 'Mouchard',
#      'links': [],
#      'coord': {'lat': '46.976805', 'lon': '5.799719'},
#      'label': 'Mouchard (Mouchard)',
#      'equipments': [],
#      'fare_zone': {'name': '0'},
#      'id': 'stop_point:OCE:SP:Lyria-87718833'},
#     'utc_arrival_time': '064100',
#     'utc_departure_time': '064300',
#     'headsign': '9260',
#     'arrival_time': '074100',
#     'departure_time': '074300'},
#    {'stop_point': {'name': 'Dole-Ville',
#      'links': [],
#      'coord': {'lat': '47.096145', 'lon': '5.488032'},
#      'label': 'Dole-Ville (Dole)',
#      'equipments': [],
#      'fare_zone': {'name': '0'},
#      'id': 'stop_point:OCE:SP:Lyria-87713412'},
#     'utc_arrival_time': '065800',
#     'utc_departure_time': '070100',
#     'headsign': '9260',
#     'arrival_time': '075800',
#     'departure_time': '080100'},
#    {'stop_point': {'name': 'Dijon-Ville',
#      'links': [],
#      'coord': {'lat': '47.323392', 'lon': '5.027278'},
#      'label': 'Dijon-Ville (Dijon)',
#      'equipments': [],
#      'fare_zone': {'name': '0'},
#      'id': 'stop_point:OCE:SP:Lyria-87713040'},
#     'utc_arrival_time': '072300',
#     'utc_departure_time': '072600',
#     'headsign': '9260',
#     'arrival_time': '082300',
#     'departure_time': '082600'},
#    {'stop_point': {'name': 'Paris-Gare-de-Lyon',
#      'links': [],
#      'coord': {'lat': '48.844924', 'lon': '2.373481'},
#      'label': 'Paris-Gare-de-Lyon (Paris)',
#      'equipments': [],
#      'fare_zone': {'name': '0'},
#      'id': 'stop_point:OCE:SP:Lyria-87686006'},
#     'utc_arrival_time': '090300',
#     'utc_departure_time': '090300',
#     'headsign': '9260',
#     'arrival_time': '100300',
#     'departure_time': '100300'}],
#   'validity_pattern': {'beginning_date': '20190303',
#    'days': ''},
#   'id': 'vehicle_journey:OCE:SN009260F02008_dst_1',
#   'trip': {'id': 'OCE:SN009260F02008', 'name': '9260'}},
#  {'status': 'past',
#   'disruption_id': '887cd394-1a83-4819-958b-a1d5abef0b82',
#   'severity': {'color': '#000000',
#    'priority': 42,
#    'name': 'unknown effect',
#    'effect': 'UNKNOWN_EFFECT'},
#   'impact_id': '887cd394-1a83-4819-958b-a1d5abef0b82',
#   'application_periods': [{'begin': '20190321T061600',
#     'end': '20190321T105459'}],
#   'updated_at': '20190325T071901',
#   'uri': '887cd394-1a83-4819-958b-a1d5abef0b82',
#   'impacted_objects': [{'impacted_stops': [{'amended_arrival_time': '051600',
#       'stop_point': {'name': 'Lyon-Perrache',
#        'links': [],
#        'coord': {'lat': '45.74878', 'lon': '4.825944'},
#        'label': 'Lyon-Perrache (Lyon)',
#        'equipments': [],
#        'fare_zone': {'name': '0'},
#        'id': 'stop_point:OCE:SP:TGV-87722025'},
#       'stop_time_effect': 'unchanged',
#       'departure_status': 'unchanged',
#       'is_detour': False,
#       'amended_departure_time': '051600',
#       'cause': '',
#       'arrival_status': 'unchanged'},
#      {'amended_arrival_time': '052400',
#       'stop_point': {'name': 'Lyon-Part-Dieu',
#        'links': [],
#        'coord': {'lat': '45.76058', 'lon': '4.859438'},
#        'label': 'Lyon-Part-Dieu (Lyon)',
#        'equipments': [],
#        'fare_zone': {'name': '0'},
#        'id': 'stop_point:OCE:SP:TGV-87723197'},
#       'stop_time_effect': 'unchanged',
#       'departure_status': 'unchanged',
#       'is_detour': False,
#       'amended_departure_time': '053000',
#       'cause': '',
#       'arrival_status': 'unchanged'},
#      {'amended_arrival_time': '073400',
#       'stop_point': {'name': 'Massy-TGV',
#        'links': [],
#        'coord': {'lat': '48.726031', 'lon': '2.261585'},
#        'label': 'Massy-TGV (Massy)',
#        'equipments': [],
#        'fare_zone': {'name': '0'},
#        'id': 'stop_point:OCE:SP:TGV-87393702'},
#       'stop_time_effect': 'unchanged',
#       'departure_status': 'unchanged',
#       'is_detour': False,
#       'amended_departure_time': '073800',
#       'cause': '',
#       'arrival_status': 'unchanged'},
#      {'amended_arrival_time': '082800',
#       'stop_point': {'name': 'Le Mans',
#        'links': [],
#        'coord': {'lat': '47.995591', 'lon': '0.192152'},
#        'label': 'Le Mans (Le Mans)',
#        'equipments': [],
#        'fare_zone': {'name': '0'},
#        'id': 'stop_point:OCE:SP:TGV-87396002'},
#       'stop_time_effect': 'unchanged',
#       'departure_status': 'unchanged',
#       'is_detour': False,
#       'amended_departure_time': '083200',
#       'cause': '',
#       'arrival_status': 'unchanged'},
#      {'amended_arrival_time': '091500',
#       'stop_point': {'name': 'Angers-St-Laud',
#        'links': [],
#        'coord': {'lat': '47.464442', 'lon': '-0.5569499999999999'},
#        'label': 'Angers-St-Laud (Angers)',
#        'equipments': [],
#        'fare_zone': {'name': '0'},
#        'id': 'stop_point:OCE:SP:TGV-87484006'},
#       'stop_time_effect': 'unchanged',
#       'departure_status': 'unchanged',
#       'is_detour': False,
#       'amended_departure_time': '091800',
#       'cause': '',
#       'arrival_status': 'unchanged'},
#      {'amended_arrival_time': '095500',
#       'stop_point': {'name': 'Nantes',
#        'links': [],
#        'coord': {'lat': '47.217516', 'lon': '-1.541943'},
#        'label': 'Nantes (Nantes)',
#        'equipments': [],
#        'fare_zone': {'name': '0'},
#        'id': 'stop_point:OCE:SP:TGV-87481002'},
#       'stop_time_effect': 'unchanged',
#       'departure_status': 'unchanged',
#       'is_detour': False,
#       'amended_departure_time': '095500',
#       'cause': '',
#       'arrival_status': 'unchanged'}],
#     'pt_object': {'embedded_type': 'trip',
#      'id': 'OCE:SN005352F03015~TGE',
#      'quality': 0,
#      'name': 'OCE:SN005352F03015~TGE',
#      'trip': {'id': 'OCE:SN005352F03015~TGE', 'name': '5352'}}}],
#   'disruption_uri': '887cd394-1a83-4819-958b-a1d5abef0b82',
#   'contributor': 'realtime.cots',
#   'cause': '',
#   'id': '887cd394-1a83-4819-958b-a1d5abef0b82'}]

# %%
for key, value in realTimes[0].items() :
    print (key)
realTimes[6]["impacted_objects"][0]["impacted_stops"][0]
# Out:
# status
# disruption_id
# severity
# impact_id
# application_periods
# updated_at
# uri
# impacted_objects
# disruption_uri
# contributor
# cause
# id
# {'amended_arrival_time': '175700',
#  'stop_point': {'name': 'Paris-Montparnasse 1-2',
#   'links': [],
#   'coord': {'lat': '48.840633', 'lon': '2.319913'},
#   'label': 'Paris-Montparnasse 1-2 (Paris)',
#   'equipments': [],
#   'fare_zone': {'name': '0'},
#   'id': 'stop_point:OCE:SP:TGVINOUI-87391003'},
#  'stop_time_effect': 'unchanged',
#  'departure_status': 'unchanged',
#  'is_detour': False,
#  'amended_departure_time': '175700',
#  'base_arrival_time': '175700',
#  'cause': '',
#  'base_departure_time': '175700',
#  'arrival_status': 'unchanged'}

# %% [markdown]
# Perfect ! We managed to print relevant data ! We just need to append each element to a list, and the job will be almost done !

# %%
lines[0]["id"]
# Out:
# 'line:OCE:230'

# %%
list_of_stations = []
list_of_lines = []
list_of_routes = []
list_of_vehicle_patterns = []
list_of_delayed_times = []

for i in stations:
    timestamp = str(datetime.datetime.now()).split('.')[0]
    a = [i["id"], i["label"], i["coord"]["lon"], i["coord"]["lat"], timestamp]
    list_of_stations.append(a)

for i in lines:
    timestamp = str(datetime.datetime.now()).split('.')[0]
    a = [i["id"], i["name"], i["commercial_mode"]["name"], timestamp]
    list_of_lines.append(a)

for i in lines:
    timestamp = str(datetime.datetime.now()).split('.')[0]
    for path in i["routes"] :
        a = [path["id"], path["name"], i["id"], i["routes"][0]["direction"]["stop_area"]["codes"][-2]["value"], 
        i["routes"][-1]["direction"]["stop_area"]["codes"][-2]["value"], timestamp]
        list_of_routes.append(a)    

for i in theoTimes:
    timestamp = str(datetime.datetime.now()).split('.')[0]
    a = [i["trip"]["id"], i["id"], i["calendars"][0]["week_pattern"]["monday"], i["calendars"][0]["week_pattern"]["tuesday"], 
         i["calendars"][0]["week_pattern"]["wednesday"], i["calendars"][0]["week_pattern"]["thursday"], 
         i["calendars"][0]["week_pattern"]["friday"], i["calendars"][0]["week_pattern"]["saturday"], 
         i["calendars"][0]["week_pattern"]["sunday"]]
    for time in i["stop_times"] :
        b = [time["stop_point"]["id"], time["arrival_time"], time["departure_time"]]
        c = [i["stop_times"][0]["stop_point"]["id"], i["stop_times"][-1]["stop_point"]["id"], timestamp]
        b = b+c
    a = a+b
    list_of_vehicle_patterns.append(a)
            
for i in realTimes :
    timestamp = str(datetime.datetime.now()).split('.')[0]
    for impact in i["impacted_objects"] :
        a = [i["updated_at"], i["impact_id"], impact["pt_object"]["id"]]
        for stop in impact["impacted_stops"] :
            dep_time = stop.get("amended_departure_time", None)
            arr_time = stop.get("amended_arrival_time", None)
            base_dep_time = stop.get("base_departure_time", None)
            base_arr_time = stop.get("base_arrival_time", None)
            b = [stop["stop_point"]["id"], stop["departure_status"], stop["arrival_status"], 
                  stop["cause"], dep_time, arr_time, base_dep_time, base_arr_time, timestamp]
        a = a+b
        list_of_delayed_times.append(a)

# %%
labels_stations = ["station_ref", "station_name", "station_longitude", "station_latitude", "last_update"]
labels_lines = ["line_ref", "line_name", "line_commercial_mode", "last_update"]
labels_routes = ["route_ref", "route_name", "line_ref", "start_station_ref", "destination_station_ref", "last_update"]
labels_vehicle_pattern = ["vehicle_journeys_ref", "vehicle_journeys_section_ref", "week_pattern_monday", "week_pattern_tuesday", "week_pattern_wednesday",
                          "week_pattern_thursday", "week_pattern_friday", "week_pattern_saturday", "week_pattern_sunday", 
                          "station_ref", "station_arrival_time", "station_departure_time", "station_name_dep", 
                          "station_name_arr", "last_update"]
labels_delayed_times = ["disruption_date", "disruption_ref", "impacted_vehicle_journeys", "impacted_arrival_station", 
                        "departure_status", "arrival_status", "delay_cause", "amended_departure_time",
                        "amended_arrival_time", "base_departure_time", "base_arrival_time", "last_update"]

# %% [markdown]
# Now that the data are almost ready, we will convert the lists in dataframes.

# %%
station = pd.DataFrame.from_records(list_of_stations, columns = labels_stations)
lines = pd.DataFrame.from_records(list_of_lines, columns = labels_lines)
routes = pd.DataFrame.from_records(list_of_routes, columns = labels_routes)
vehicle_pattern = pd.DataFrame.from_records(list_of_vehicle_patterns, columns = labels_vehicle_pattern)
disruptions = pd.DataFrame.from_records(list_of_delayed_times, columns = labels_delayed_times)

# %%
station.station_ref = station.station_ref.replace({r'stop_point\:OCE\:SP\:':''}, regex = True)

lines.line_ref = lines.line_ref.replace({r'line\:OCE\:' : ''}, regex = True)

routes.line_ref = routes.line_ref.replace({r'line\:OCE\:' : ''}, regex = True)
routes.route_ref = routes.route_ref.replace({r'route\:OCE\:' : ''}, regex = True)

vehicle_pattern.vehicle_journeys_ref = vehicle_pattern.vehicle_journeys_ref.replace({
    r'OCE\:':''}, regex = True)
vehicle_pattern.vehicle_journeys_section_ref = vehicle_pattern.vehicle_journeys_section_ref.replace({
    r'vehicle_journey\:OCE\:':''}, regex = True)
vehicle_pattern.station_ref = vehicle_pattern.station_ref.replace({r'stop_point\:OCE\:SP\:':''}, regex = True)
vehicle_pattern.station_name_dep = vehicle_pattern.station_name_dep.replace({r'stop_point\:OCE\:SP\:':''}, regex = True)
vehicle_pattern.station_name_arr = vehicle_pattern.station_name_arr.replace({r'stop_point\:OCE\:SP\:':''}, regex = True)

disruptions.impacted_vehicle_journeys = disruptions.impacted_vehicle_journeys.replace({r'OCE\:':''}, regex = True)
disruptions.impacted_arrival_station =disruptions .impacted_arrival_station.replace({r'stop_point\:OCE\:SP\:':''}, regex = True)

# %%
coltypes = print(station.dtypes, "\n", "\n",lines.dtypes, "\n", "\n", routes.dtypes, "\n", "\n",
                 vehicle_pattern.dtypes, "\n", "\n", disruptions.dtypes)
coltypes
# Out:
# station_ref          object
# station_name         object
# station_longitude    object
# station_latitude     object
# last_update          object
# dtype: object
#
#  line_ref                object
# line_name               object
# line_commercial_mode    object
# last_update             object
# dtype: object
#
#  route_ref                  object
# route_name                 object
# line_ref                   object
# start_station_ref          object
# destination_station_ref    object
# last_update                object
# dtype: object
#
#  vehicle_journeys_ref            object
# vehicle_journeys_section_ref    object
# week_pattern_monday               bool
# week_pattern_tuesday              bool
# week_pattern_wednesday            bool
# week_pattern_thursday             bool
# week_pattern_friday               bool
# week_pattern_saturday             bool
# week_pattern_sunday               bool
# station_ref                     object
# station_arrival_time            object
# station_departure_time          object
# station_name_dep                object
# station_name_arr                object
# last_update                     object
# dtype: object
#
#  disruption_date              object
# disruption_ref               object
# impacted_vehicle_journeys    object
# impacted_arrival_station     object
# departure_status             object
# arrival_status               object
# delay_cause                  object
# amended_departure_time       object
# amended_arrival_time         object
# base_departure_time          object
# base_arrival_time            object
# last_update                  object
# dtype: object

# %%
station[["station_latitude",
         "station_longitude"]] = station[["station_latitude", "station_longitude"]].apply(pd.to_numeric)

routes[["start_station_ref", "destination_station_ref"]] = routes[["start_station_ref", "destination_station_ref"]].apply(pd.to_numeric)

vehicle_pattern['station_arrival_time'] = pd.to_datetime(vehicle_pattern['station_arrival_time'],format= '%H%M%S').dt.time
vehicle_pattern['station_departure_time'] = pd.to_datetime(vehicle_pattern['station_departure_time'],format= '%H%M%S').dt.time

disruptions['disruption_date'] = pd.to_datetime(disruptions['disruption_date'],format= '%Y%m%dT%H%M%S' )
disruptions['amended_departure_time'] = pd.to_datetime(disruptions['amended_departure_time'],format= '%H%M%S' ).dt.time
disruptions['amended_arrival_time'] = pd.to_datetime(disruptions['amended_arrival_time'],format= '%H%M%S' ).dt.time
disruptions['base_departure_time'] = pd.to_datetime(disruptions['base_departure_time'],format= '%H%M%S' ).dt.time
disruptions['base_arrival_time'] = pd.to_datetime(disruptions['base_arrival_time'],format= '%H%M%S' ).dt.time

station["last_update"] = pd.to_datetime(station['last_update'],format= '%Y-%m-%d %H:%M:%S')
lines["last_update"] = pd.to_datetime(station['last_update'],format= '%Y-%m-%d %H:%M:%S')
routes["last_update"] = pd.to_datetime(station['last_update'],format= '%Y-%m-%d %H:%M:%S')
vehicle_pattern["last_update"] = pd.to_datetime(station['last_update'],format= '%Y-%m-%d %H:%M:%S')
disruptions["last_update"] = pd.to_datetime(station['last_update'],format= '%Y-%m-%d %H:%M:%S')

# %%
coltypes = print(station.dtypes, "\n", "\n",lines.dtypes, "\n", "\n", routes.dtypes, "\n", "\n",
                 vehicle_pattern.dtypes, "\n", "\n", disruptions.dtypes)
coltypes
# Out:
# station_ref                  object
# station_name                 object
# station_longitude           float64
# station_latitude            float64
# last_update          datetime64[ns]
# dtype: object
#
#  line_ref                        object
# line_name                       object
# line_commercial_mode            object
# last_update             datetime64[ns]
# dtype: object
#
#  route_ref                          object
# route_name                         object
# line_ref                           object
# start_station_ref                   int64
# destination_station_ref             int64
# last_update                datetime64[ns]
# dtype: object
#
#  vehicle_journeys_ref                    object
# vehicle_journeys_section_ref            object
# week_pattern_monday                       bool
# week_pattern_tuesday                      bool
# week_pattern_wednesday                    bool
# week_pattern_thursday                     bool
# week_pattern_friday                       bool
# week_pattern_saturday                     bool
# week_pattern_sunday                       bool
# station_ref                             object
# station_arrival_time                    object
# station_departure_time                  object
# station_name_dep                        object
# station_name_arr                        object
# last_update                     datetime64[ns]
# dtype: object
#
#  disruption_date              datetime64[ns]
# disruption_ref                       object
# impacted_vehicle_journeys            object
# impacted_arrival_station             object
# departure_status                     object
# arrival_status                       object
# delay_cause                          object
# amended_departure_time               object
# amended_arrival_time                 object
# base_departure_time                  object
# base_arrival_time                    object
# last_update                  datetime64[ns]
# dtype: object

# %%
routes
# Out:
#                            route_ref  \
# 0        230-Lyria-85011205-87686006
# 1        230-Lyria-87686006-85011205
# 2        231-Lyria-85010082-87686006
# 3        231-Lyria-85011205-87686006
# 4        231-Lyria-87686006-85010082
# 5        231-Lyria-87686006-85011205
# 6        232-Lyria-85000109-87686006
# 7        232-Lyria-85030007-87686006
# 8        232-Lyria-85070003-87686006
# 9        232-Lyria-87686006-85000109
# 10       232-Lyria-87686006-85030007
# 11       232-Lyria-87686006-85070003
# 12         137-TGV-87391003-87485003
# 13         137-TGV-87391003-87571000
# 14         137-TGV-87391003-87575001
# 15         137-TGV-87391003-87581009
# 16         137-TGV-87391003-87582668
# 17         137-TGV-87391003-87611004
# 18         137-TGV-87485003-87391003
# 19         137-TGV-87571000-87391003
# 20         137-TGV-87575001-87391003
# 21         137-TGV-87581009-87391003
# 22         137-TGV-87582668-87391003
# 23         137-TGV-87677005-87391003
# 24    137-TGVINOUI-87391003-71116000
# 25    137-TGVINOUI-87391003-87485003
# 26    137-TGVINOUI-87391003-87571000
# 27    137-TGVINOUI-87391003-87575001
# 28    137-TGVINOUI-87391003-87581009
# 29    137-TGVINOUI-87391003-87582668
# ..                               ...
# 373  1041887-OUIGO-87756056-87686006
# 374        129-TGV-87471003-87722025
# 375        129-TGV-87471003-87751008
# 376        129-TGV-87471003-87773002
# 377        129-TGV-87481002-87722025
# 378        129-TGV-87481002-87751008
# 379        129-TGV-87481002-87773002
# 380        129-TGV-87722025-87471003
# 381        129-TGV-87722025-87481002
# 382        129-TGV-87751008-87471003
# 383        129-TGV-87751008-87481002
# 384        129-TGV-87773002-87471003
# 385        129-TGV-87773002-87481002
# 386      129-Train-87751008-87481002
# 387     829862-TGV-87141002-87722025
# 388     829862-TGV-87182063-87223263
# 389     829862-TGV-87286005-87182063
# 390     829862-TGV-87413013-87751008
# 391     829862-TGV-87713040-87756056
# 392     829862-TGV-87722025-87141002
# 393     829862-TGV-87723197-87751008
# 394     829862-TGV-87723197-87756056
# 395     829862-TGV-87751008-82001000
# 396     829862-TGV-87751008-87212027
# 397     829862-TGV-87751008-87413013
# 398     829862-TGV-87756056-87713040
# 399     829862-TGV-87756056-87722025
# 400     829862-TGV-87756056-87723197
# 401     829862-TGV-87773002-82001000
# 402     829862-TGV-87773002-87192039
#
#                                             route_name line_ref  \
# 0             Lausanne vers Paris-Gare-de-Lyon (Lyria)      230
# 1             Paris-Gare-de-Lyon vers Lausanne (Lyria)      230
# 2               Genève vers Paris-Gare-de-Lyon (Lyria)      231
# 3             Lausanne vers Paris-Gare-de-Lyon (Lyria)      231
# 4               Paris-Gare-de-Lyon vers Genève (Lyria)      231
# 5             Paris-Gare-de-Lyon vers Lausanne (Lyria)      231
# 6            Basel-SBB vers Paris-Gare-de-Lyon (Lyria)      232
# 7            Zurich-Hb vers Paris-Gare-de-Lyon (Lyria)      232
# 8                 Bern vers Paris-Gare-de-Lyon (Lyria)      232
# 9            Paris-Gare-de-Lyon vers Basel-SBB (Lyria)      232
# 10           Paris-Gare-de-Lyon vers Zurich-Hb (Lyria)      232
# 11                Paris-Gare-de-Lyon vers Bern (Lyria)      232
# 12   Paris-Montparnasse 1-2 vers La Rochelle-Ville ...      137
# 13             Paris-Montparnasse 1-2 vers Tours (TGV)      137
# 14          Paris-Montparnasse 1-2 vers Poitiers (TGV)      137
# 15   Paris-Montparnasse 1-2 vers Bordeaux-St-Jean (...      137
# 16          Paris-Montparnasse 1-2 vers Arcachon (TGV)      137
# 17   Paris-Montparnasse 1-2 vers Toulouse-Matabiau ...      137
# 18   La Rochelle-Ville vers Paris-Montparnasse 1-2 ...      137
# 19             Tours vers Paris-Montparnasse 1-2 (TGV)      137
# 20          Poitiers vers Paris-Montparnasse 1-2 (TGV)      137
# 21   Bordeaux-St-Jean vers Paris-Montparnasse 1-2 (...      137
# 22          Arcachon vers Paris-Montparnasse 1-2 (TGV)      137
# 23           Hendaye vers Paris-Montparnasse 1-2 (TGV)      137
# 24        Paris-Montparnasse 1-2 vers Irun (TGV INOUI)      137
# 25   Paris-Montparnasse 1-2 vers La Rochelle-Ville ...      137
# 26       Paris-Montparnasse 1-2 vers Tours (TGV INOUI)      137
# 27    Paris-Montparnasse 1-2 vers Poitiers (TGV INOUI)      137
# 28   Paris-Montparnasse 1-2 vers Bordeaux-St-Jean (...      137
# 29    Paris-Montparnasse 1-2 vers Arcachon (TGV INOUI)      137
# ..                                                 ...      ...
# 373         Nice-Ville vers Paris-Gare-de-Lyon (OUIGO)  1041887
# 374                    Rennes vers Lyon-Perrache (TGV)      129
# 375             Rennes vers Marseille-St-Charles (TGV)      129
# 376           Rennes vers Montpellier-Saint-Roch (TGV)      129
# 377                    Nantes vers Lyon-Perrache (TGV)      129
# 378             Nantes vers Marseille-St-Charles (TGV)      129
# 379           Nantes vers Montpellier-Saint-Roch (TGV)      129
# 380                    Lyon-Perrache vers Rennes (TGV)      129
# 381                    Lyon-Perrache vers Nantes (TGV)      129
# 382             Marseille-St-Charles vers Rennes (TGV)      129
# 383             Marseille-St-Charles vers Nantes (TGV)      129
# 384           Montpellier-Saint-Roch vers Rennes (TGV)      129
# 385           Montpellier-Saint-Roch vers Nantes (TGV)      129
# 386           Marseille-St-Charles vers Nantes (Train)      129
# 387               Nancy-Ville vers Lyon-Perrache (TGV)   829862
# 388                   Mulhouse vers Lille Europe (TGV)   829862
# 389                 Lille Flandres vers Mulhouse (TGV)   829862
# 390           Le Havre vers Marseille-St-Charles (TGV)   829862
# 391                  Dijon-Ville vers Nice-Ville (TGV)   829862
# 392               Lyon-Perrache vers Nancy-Ville (TGV)   829862
# 393     Lyon-Part-Dieu vers Marseille-St-Charles (TGV)   829862
# 394               Lyon-Part-Dieu vers Nice-Ville (TGV)   829862
# 395         Marseille-St-Charles vers Luxembourg (TGV)   829862
# 396         Marseille-St-Charles vers Strasbourg (TGV)   829862
# 397           Marseille-St-Charles vers Le Havre (TGV)   829862
# 398                  Nice-Ville vers Dijon-Ville (TGV)   829862
# 399                Nice-Ville vers Lyon-Perrache (TGV)   829862
# 400               Nice-Ville vers Lyon-Part-Dieu (TGV)   829862
# 401       Montpellier-Saint-Roch vers Luxembourg (TGV)   829862
# 402       Montpellier-Saint-Roch vers Metz-Ville (TGV)   829862
#
#      start_station_ref  destination_station_ref         last_update
# 0             87686006                 85011205 2019-03-25 16:49:51
# 1             87686006                 85011205 2019-03-25 16:49:51
# 2             87686006                 85010082 2019-03-25 16:49:51
# 3             87686006                 85010082 2019-03-25 16:49:51
# 4             87686006                 85010082 2019-03-25 16:49:51
# 5             87686006                 85010082 2019-03-25 16:49:51
# 6             87686006                 85070003 2019-03-25 16:49:51
# 7             87686006                 85070003 2019-03-25 16:49:51
# 8             87686006                 85070003 2019-03-25 16:49:51
# 9             87686006                 85070003 2019-03-25 16:49:51
# 10            87686006                 85070003 2019-03-25 16:49:51
# 11            87686006                 85070003 2019-03-25 16:49:51
# 12            87485003                 87391003 2019-03-25 16:49:51
# 13            87485003                 87391003 2019-03-25 16:49:51
# 14            87485003                 87391003 2019-03-25 16:49:51
# 15            87485003                 87391003 2019-03-25 16:49:51
# 16            87485003                 87391003 2019-03-25 16:49:51
# 17            87485003                 87391003 2019-03-25 16:49:51
# 18            87485003                 87391003 2019-03-25 16:49:51
# 19            87485003                 87391003 2019-03-25 16:49:51
# 20            87485003                 87391003 2019-03-25 16:49:51
# 21            87485003                 87391003 2019-03-25 16:49:51
# 22            87485003                 87391003 2019-03-25 16:49:51
# 23            87485003                 87391003 2019-03-25 16:49:51
# 24            87485003                 87391003 2019-03-25 16:49:51
# 25            87485003                 87391003 2019-03-25 16:49:51
# 26            87485003                 87391003 2019-03-25 16:49:51
# 27            87485003                 87391003 2019-03-25 16:49:51
# 28            87485003                 87391003 2019-03-25 16:49:51
# 29            87485003                 87391003 2019-03-25 16:49:51
# ..                 ...                      ...                 ...
# 373           87751008                 87686006 2019-03-25 16:49:51
# 374           87722025                 87481002 2019-03-25 16:49:51
# 375           87722025                 87481002 2019-03-25 16:49:51
# 376           87722025                 87481002 2019-03-25 16:49:51
# 377           87722025                 87481002 2019-03-25 16:49:51
# 378           87722025                 87481002 2019-03-25 16:49:51
# 379           87722025                 87481002 2019-03-25 16:49:51
# 380           87722025                 87481002 2019-03-25 16:49:51
# 381           87722025                 87481002 2019-03-25 16:49:51
# 382           87722025                 87481002 2019-03-25 16:49:51
# 383           87722025                 87481002 2019-03-25 16:49:51
# 384           87722025                 87481002 2019-03-25 16:49:51
# 385           87722025                 87481002 2019-03-25 16:49:51
# 386           87722025                 87481002 2019-03-25 16:49:51
# 387           87722025                 87192039 2019-03-25 16:49:51
# 388           87722025                 87192039 2019-03-25 16:49:51
# 389           87722025                 87192039 2019-03-25 16:49:51
# 390           87722025                 87192039 2019-03-25 16:49:51
# 391           87722025                 87192039                 NaT
# 392           87722025                 87192039                 NaT
# 393           87722025                 87192039                 NaT
# 394           87722025                 87192039                 NaT
# 395           87722025                 87192039                 NaT
# 396           87722025                 87192039                 NaT
# 397           87722025                 87192039                 NaT
# 398           87722025                 87192039                 NaT
# 399           87722025                 87192039                 NaT
# 400           87722025                 87192039                 NaT
# 401           87722025                 87192039                 NaT
# 402           87722025                 87192039                 NaT
#
# [403 rows x 6 columns]

# %%
vehicle_pattern.station_name_dep = vehicle_pattern.station_name_dep.replace({r'stop_point\:OCE\:SP\:':''}, regex = True)
vehicle_pattern.station_name_arr = vehicle_pattern.station_name_arr.replace({r'[^0-9.]':''}, regex = True)

vehicle_pattern["route_ref"] = vehicle_pattern.apply(lambda row: row.station_name_dep + "-" + row.station_name_arr, axis=1)
vehicle_pattern = vehicle_pattern.drop('station_name_dep', 1)
vehicle_pattern = vehicle_pattern.drop('station_name_arr', 1)

# %%
vehicle_pattern = vehicle_pattern[[c for c in vehicle_pattern if c not in ['last_update']] 
       + ['last_update']]
vehicle_pattern.station_ref = vehicle_pattern.station_ref.replace({r'[^0-9.]':''}, regex = True)
station.station_ref = station.station_ref.replace({r'[^0-9.]':''}, regex = True)

# %%
station = station.drop_duplicates(["station_ref"])

# %% [markdown]
# Here, you can choose to display any table to have a view of the data. Please type any name of dataframe (station, lines, routes, vehicle_pattern, disruptions).

# %%
routes = routes.replace({"last_update":{None : timestamp}}).ffill()

# %%
#!{sys.executable} -m pip install psycopg2-binary;

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:admin@localhost:5432/SNCF')
lines.to_sql('lines', engine, if_exists = "append", index = False, schema = "rail_network")
station.to_sql('stations', engine, schema = "rail_network", if_exists = "append", index = False)
routes.to_sql('routes', engine, if_exists = "append", index = False, schema = "rail_network")
vehicle_pattern.to_sql('vehicle_pattern', engine, if_exists = "append", index = False)
disruptions.to_sql('disruptions', engine, if_exists = "append", index = False)
